# %% [markdown]
# 1- CONFIGURAÇÕES INICIAIS :

# %% [markdown]
# 1.1- Importar bibliotecas :

# %%
#comando import para importar as bibliotecas

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1.2- Importar a tabela :

# %%
#comandos para importar e printar tabela com informações do foguete

df = pd.read_excel('Dados.xlsx')
display (df)
# Out:
#      Longitude    Latitude  Altitude (m)               counter:#sat:time (s)  \
# 0   -120.068167  36.512440            53  !-- 38490 sats:11 UTC 17:44:36 -->
# 1   -120.068167  36.512442            54  !-- 38505 sats:11 UTC 17:44:37 -->
# 2   -120.068167  36.512443            54  !-- 38520 sats:11 UTC 17:44:38 -->
# 3   -120.068167  36.512445            54  !-- 38535 sats:11 UTC 17:44:39 -->
# 4   -120.068168  36.512445            54  !-- 38550 sats:11 UTC 17:44:40 -->
# ..          ...        ...           ...                                 ...
# 261 -120.076215  36.509537            51  !-- 42405 sats:11 UTC 17:48:57 -->
# 262 -120.076213  36.509537            51  !-- 42420 sats:11 UTC 17:48:58 -->
# 263 -120.076213  36.509537            51  !-- 42435 sats:11 UTC 17:48:59 -->
# 264 -120.076213  36.509537            51  !-- 42450 sats:11 UTC 17:49:00 -->
# 265 -120.076213  36.509537            50  !-- 42465 sats:11 UTC 17:49:01 -->
#
#      East (ft)  North (ft)  Altitude (ft)  Altitude   (ft)  Time (s)  \
# 0            0           0            174                3         1
# 1            0           1            177                6         2
# 2            0           1            177                6         3
# 3            0           2            177                6         4
# 4            0           2            177                6         5
# ..         ...         ...            ...              ...       ...
# 261      -2358       -1058            167               -4       262
# 262      -2357       -1058            167               -4       263
# 263      -2357       -1058            167               -4       264
# 264      -2357       -1058            167               -4       265
# 265      -2357       -1058            164               -7       266
#
#      Offset Time (s)  Verticle Velocity (fps)  Verticle Velocity (mph)  \
# 0                -18                      NaN                      NaN
# 1                -17                      3.3                      2.0
# 2                -16                      0.0                      0.0
# 3                -15                      0.0                      0.0
# 4                -14                      0.0                      0.0
# ..               ...                      ...                      ...
# 261              243                      0.0                      0.0
# 262              244                      0.0                      0.0
# 263              245                      0.0                      0.0
# 264              246                      0.0                      0.0
# 265              247                     -3.3                     -2.0
#
#      Ground Distance Traveled (ft)  Ground velocity (mph)  Acceleretion (g/s)
# 0                              NaN                    NaN                 NaN
# 1                              1.0                    NaN                 NaN
# 2                              1.0                    NaN                 NaN
# 3                              2.0                    NaN                 NaN
# 4                              2.0                    NaN                 NaN
# ..                             ...                    ...                 ...
# 261                         7632.0                    0.0                 0.0
# 262                         7633.0                    0.4                 0.0
# 263                         7633.0                    0.0                 0.0
# 264                         7633.0                    0.0                 0.0
# 265                         7633.0                    0.0                -0.1
#
# [266 rows x 15 columns]

# %% [markdown]
# 1.3- Filtrar os dados que serão utilizados adiante :

# %%
#criando uma tabela secundária com as principais informações que serão usadas no cálculo estatístico

df_main = df[['Altitude (m)','Verticle Velocity (mph)','Ground velocity (mph)','Acceleretion (g/s)']]

display(df_main)
# Out:
#      Altitude (m)  Verticle Velocity (mph)  Ground velocity (mph)  \
# 0              53                      NaN                    NaN
# 1              54                      2.0                    NaN
# 2              54                      0.0                    NaN
# 3              54                      0.0                    NaN
# 4              54                      0.0                    NaN
# ..            ...                      ...                    ...
# 261            51                      0.0                    0.0
# 262            51                      0.0                    0.4
# 263            51                      0.0                    0.0
# 264            51                      0.0                    0.0
# 265            50                     -2.0                    0.0
#
#      Acceleretion (g/s)
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 261                 0.0
# 262                 0.0
# 263                 0.0
# 264                 0.0
# 265                -0.1
#
# [266 rows x 4 columns]

# %% [markdown]
# 2- DADOS ESTATÍSTICOS :

# %% [markdown]
# 2.1- Média :

# %%
#usando a função .mean() para calcular a média das colunas 

df_main.mean()
# Out:
# Altitude (m)               1382.984962
# Verticle Velocity (mph)       0.086792
# Ground velocity (mph)        20.011538
# Acceleretion (g/s)            0.001154
# dtype: float64

# %% [markdown]
# 2.2- Mediana :

# %%
#usando a função .median() para calcular a mediana das colunas 

df_main.median()
# Out:
# Altitude (m)               1286.5
# Verticle Velocity (mph)     -38.0
# Ground velocity (mph)        11.5
# Acceleretion (g/s)            0.0
# dtype: float64

# %% [markdown]
# 3- MÁXIMOS E MÍNIMOS :

# %% [markdown]
# 3.1- Máximos :

# %%
#usando a função .max() é possível calcular o valor máximo de cada coluna selecionada

df_main.max()
# Out:
# Altitude (m)               3329.0
# Verticle Velocity (mph)     640.0
# Ground velocity (mph)       147.0
# Acceleretion (g/s)           12.5
# dtype: float64

# %% [markdown]
# 3.2- Mínimos :

# %%
#usando a função .min() é possível calcular o valor mínimo de cada coluna selecionada

df_main.min()
# Out:
# Altitude (m)               50.0
# Verticle Velocity (mph)   -49.0
# Ground velocity (mph)       0.0
# Acceleretion (g/s)         -2.4
# dtype: float64

# %% [markdown]
# 4- GRÁFICOS :

# %% [markdown]
# 4.1- Aceleração(g/s) x Tempo(s) :

# %%
#criar gráficos com a biblioteca matplotlib, a função .plot(p1, p2) usa 2 parâmetros para os eixos x e y respectivamente; .show apresenta e .title, .label são legendas do gráfico

#gráfico da aceleração em função do tempo:
acc = df_main[['Acceleretion (g/s)']]
tempo = df[['Time (s)']]
plt.plot(tempo, acc)
plt.title('Aceleração(g/s) x Tempo(s)')
plt.xlabel('Tempo (s)')
plt.ylabel('Aceleração(g/s)')
plt.show()

# %% [markdown]
# 4.2- Altiutde (m) x Distância horizontal (ft) :

# %%
#gráfico da altitude em função do distância horizontal percorrida:

disth = df[['Ground Distance Traveled (ft)']]
altura = df_main[['Altitude (m)']]
plt.plot(disth, altura)
plt.title('Altiutde (m) x Distância horizontal (ft)')
plt.xlabel('Distância horizontal (ft)')
plt.ylabel('Altiutde (m)')
plt.show()

# %% [markdown]
# 4.3- Altitude (m) x Tempo (s) :

# %%
#gráfico da altitude em função do tempo:

plt.plot(tempo, altura)
plt.title('Altitude (m) x Tempo (s)')
plt.xlabel('Tempo (s)')
plt.ylabel('Altitude (m)')
plt.show()

# %% [markdown]
# 4.4- Distância horizontal(ft) x Tempo (s) :

# %%
#gráfico da distância horizontal percorrida em função do tempo:

plt.plot(tempo, disth)
plt.title('Distância horizontal(ft) x Tempo (s)')
plt.xlabel('Tempo (s)')
plt.ylabel('Distância horizontal(ft)')
plt.show()

# %% [markdown]
# 4.5 - Velocidade vertical (mph) x Tempo (s) :

# %%
#gráfico da velocidade vertical em função do tempo:

vv = df_main[['Verticle Velocity (mph)']]
plt.plot(tempo, vv)
plt.title('Velocidade vertical (mph) x Tempo (s)')
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade vertical (mph)')
plt.show()

# %% [markdown]
# 4.6 - Velocidade horizontal (mph) x Tempo (s) :

# %%
#gráfico da velocidade horizontal em função do tempo:

vh = df_main[['Ground velocity (mph)']]
plt.plot(tempo, vh)
plt.title('Velocidade horizontal (mph) x Tempo (s)')
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade horizontal (mph)')
plt.show()
